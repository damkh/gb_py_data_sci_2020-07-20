# %%
import seaborn as sns

# %%
titanic = sns.load_dataset("titanic")

# %%
ax = sns.countplot(x="who", data=titanic)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ax = sns.countplot(x="class", hue="who", data=titanic)

# %% [markdown]
# Вычислить:
# 1) $-\frac{6}{30} \cdot \frac{80}{36} - \frac{70}{18}$
# 2) $-\frac{70}{18} - \frac{6}{30} \cdot \frac{80}{36}$
# 3) $-\left(\frac{70}{18}\right)^2 - \frac{6}{30} \cdot \frac{80}{36}$
# 4) $-\frac{2}{36} \cdot \frac{32}{20} - \frac{25}{3}$
# 5) $-\frac{25}{3} - \frac{2}{36} \cdot \frac{32}{20}$
# 6) $-\left(\frac{25}{3}\right)^2 - \frac{2}{36} \cdot \frac{32}{20}$
# 7) $ \frac{8}{48} \cdot \frac{80}{24} + \frac{25}{24}$
# 8) $-\frac{25}{24} + \frac{8}{48} \cdot \frac{80}{24}$
# 9) $ \left(\frac{25}{24}\right)^2 + \frac{8}{48} \cdot \frac{80}{24}$
# 10) $ \frac{8}{6} \cdot \frac{72}{28} + \frac{25}{15}$
# 11) $-\frac{25}{15} + \frac{8}{6} \cdot \frac{72}{28}$
# 12) $ \left(\frac{25}{15}\right)^2 + \frac{8}{6} \cdot \frac{72}{28}$
# 13) $ \frac{4}{12} \cdot \frac{48}{32} + \frac{30}{6}$
# 14) $-\frac{30}{6} + \frac{4}{12} \cdot \frac{48}{32}$
# 15) $ \left(\frac{30}{6}\right)^2 + \frac{4}{12} \cdot \frac{48}{32}$
# 16) $-\frac{12}{54} \cdot \frac{40}{36} - \frac{60}{27}$
# 17) $-\frac{60}{27} - \frac{12}{54} \cdot \frac{40}{36}$
# 18) $-\left(\frac{60}{27}\right)^2 - \frac{12}{54} \cdot \frac{40}{36}$
# 19) $-\frac{4}{36} \cdot \frac{72}{20} - \frac{30}{12}$
# 20) $ \frac{30}{12} - \frac{4}{36} \cdot \frac{72}{20}$
# 21) $-\left(\frac{30}{12}\right)^3 - \frac{4}{36} \cdot \frac{72}{20}$
# 22) $-\frac{2}{30} \cdot \frac{24}{36} - \frac{50}{27}$
# 23) $ \frac{50}{27} - \frac{2}{30} \cdot \frac{24}{36}$
# 24) $-\left(\frac{50}{27}\right)^3 - \frac{2}{30} \cdot \frac{24}{36}$
# 25) $ \frac{12}{24} \cdot \frac{72}{20} + \frac{60}{24}$
# 26) $-\frac{60}{24} + \frac{12}{24} \cdot \frac{72}{20}$
# 27) $ \left(\frac{60}{24}\right)^2 + \frac{12}{24} \cdot \frac{72}{20}$
# 28) $ \frac{4}{48} \cdot \frac{56}{28} + \frac{55}{15}$
# 29) $ \frac{55}{15} + \frac{4}{48} \cdot \frac{56}{28}$
# 30) $ \left(\frac{55}{15}\right)^3 + \frac{4}{48} \cdot \frac{56}{28}$
# 31) $-\frac{8}{48} \cdot \frac{32}{28} - \frac{60}{12}$
# 32) $-\frac{60}{12} - \frac{8}{48} \cdot \frac{32}{28}$
# 33) $-\left(\frac{60}{12}\right)^2 - \frac{8}{48} \cdot \frac{32}{28}$
# 34) $-\frac{4}{18} \cdot \frac{56}{28} - \frac{10}{24}$
# 35) $ \frac{10}{24} - \frac{4}{18} \cdot \frac{56}{28}$
# 36) $-\left(\frac{10}{24}\right)^3 - \frac{4}{18} \cdot \frac{56}{28}$
